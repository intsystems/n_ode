# %% [markdown]
# # Vizualizing phase trajectories of acceleration of different body movements

# %%
try:
    if _ALREADY_RUN: pass
except NameError:
    # %cd ../..
    _ALREADY_RUN = True

# %%
from omegaconf import OmegaConf
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
import pandas as pd
import scipy.linalg as linalg
from sklearn.decomposition import PCA

from experiment.motion_sense.utils.raw_data_loading import create_time_series, set_data_types

# %%
SEED = 123
np.random.seed(SEED)

# %%
config = OmegaConf.load("/Users/sem-k32/10_sem/n_ode/experiment/motion_sense/config.yaml")

# %%
subjects = pd.read_csv(config.data_dir + "/data_subjects_info.csv")
subjects.head()
# Out:
#    code  weight  height  age  gender
# 0     1     102     188   46       1
# 1     2      72     180   28       1
# 2     3      48     161   28       0
# 3     4      90     176   31       1
# 4     5      48     164   23       0

# %%
# subjects_sample = subjects["code"].sample(2).tolist()
# subjects_sample
subjects_sample = [0, 4]
subjects_sample
# Out:
# [0, 4]

# %%
for act, activity_codes in config.activity_codes.items():
    print(act)
    act_code = activity_codes[0]
    for data_type in ["attitude", "rotationRate", "userAcceleration"]:
        print(data_type)
        dt_columns = set_data_types([data_type])
        act_labels = [act]
        trial_codes = [[act_code]]
        ts_df = create_time_series(
            config.data_dir, dt_columns, act_labels, trial_codes, mode="raw"
        )
        ts_df = ts_df[ts_df["id"].isin(subjects_sample)]
        ts_df = ts_df.iloc[::20]
        ts_df["t"] = ts_df.groupby("id", group_keys=False).apply(
            lambda d: pd.Series(range(d.shape[0]), index=d.index)
        )
        # print(ts_df.head())
        # break
        for ts_name in ts_df.columns[:3]:
            px.line(
                ts_df, x="t", y=ts_name, color="id"
            ).show()
# Out:
# dws
# attitude
# /var/folders/tv/q1p26lz50rb2w5jz_krw4gqh0000gn/T/ipykernel_37994/2024845206.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ts_df["t"] = ts_df.groupby("id", group_keys=False).apply(
# rotationRate
# /var/folders/tv/q1p26lz50rb2w5jz_krw4gqh0000gn/T/ipykernel_37994/2024845206.py:14: FutureWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   ts_df["t"] = ts_df.groupby("id", group_keys=False).apply(
# ...
