# %% [markdown]
# # Vizualizing our time series model and approach

# %%
import numpy as np
import pandas as pd
from scipy.integrate import solve_ivp
import plotly.express as px
import plotly.graph_objects as go

# %%
def lorenz_system(t, state, sigma=10.0, rho=28.0, beta=8/3):
    """Lorenz system differential equations."""
    x, y, z = state
    
    dxdt = sigma * (y - x)
    dydt = x * (rho - z) - y
    dzdt = x * y - beta * z
    
    return [dxdt, dydt, dzdt]

def compute_lorenz_trajectory(initial_state=[1.0, 1.0, 1.0], 
                              t_span=(0, 100), 
                              t_eval=None,
                              sigma=10.0, 
                              rho=28.0, 
                              beta=8/3):
    """
    Compute trajectory of the Lorenz system.
    
    Parameters:
    -----------
    initial_state : list or array
        Initial conditions [x0, y0, z0]
    t_span : tuple
        Time span for integration (start, end)
    t_eval : array or None
        Times at which to store the computed solution
    sigma, rho, beta : float
        Lorenz system parameters
        
    Returns:
    --------
    sol : OdeResult
        Solution object containing time points and state values
    """
    # Solve the differential equations
    sol = solve_ivp(
        lorenz_system,
        t_span,
        initial_state,
        args=(sigma, rho, beta),
        t_eval=t_eval,
        method='RK45',
        rtol=1e-8,
        atol=1e-8,
        dense_output=True
    )
    
    return sol

# %%
trajectory = compute_lorenz_trajectory()
trajectory
# Out:
#   message: The solver successfully reached the end of the integration interval.
#   success: True
#    status: 0
#         t: [ 0.000e+00  4.207e-03 ...  9.999e+01  1.000e+02]
#         y: [[ 1.000e+00  1.002e+00 ...  2.438e+00  2.586e+00]
#             [ 1.000e+00  1.109e+00 ...  4.639e+00  4.929e+00]
#             [ 1.000e+00  9.933e-01 ...  8.343e+00  8.277e+00]]
#       sol: <scipy.integrate._ivp.common.OdeSolution object at 0x1170b5be0>
#  t_events: None
#  y_events: None
#      nfev: 62138
#      njev: 0
#       nlu: 0

# %%
trajectory.y[0].shape
# Out:
# (10150,)

# %%
# Calculate axis ranges for consistent scaling
x_range = [trajectory.y[0].min() - 2, trajectory.y[0].max() + 2]
y_range = [trajectory.y[1].min() - 2, trajectory.y[1].max() + 2]
z_range = [trajectory.y[2].min() - 2, trajectory.y[2].max() + 2]

layout = dict(
    width=800,
    height=700,
    margin=dict(l=0, r=0, b=0, t=80),
)

# %%
fig = go.Figure(data=go.Scatter3d(
    x=trajectory.y[0], y=trajectory.y[1], z=trajectory.y[2],
    mode="lines",
    line=dict(
        color='darkblue',
        width=2
    )
))
fig.update_layout(layout)
fig

# %%
traj_norm =
